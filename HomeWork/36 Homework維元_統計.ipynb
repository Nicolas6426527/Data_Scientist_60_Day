# %% [markdown]
# ## 作業:
# 某工廠想知道兩條不同的生產線的產品不良率是否有所不同，由兩條生產線中各抽取 300 個樣本，第一組有  75 個不良品，第二組有 30 個不良品，我們可以宣稱生產線所生產出的產品不良率不相同? (以 0.05 為顯著水準)?
# (提示:透過課程投影片的步驟，需思考 𝐻_0、 𝐻_1 的寫法和範例不同唷。)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns

# %%
'''
你的答案
'''
print("H_0:p1=p2")
print("H_1:p1≠p2")
import statsmodels.stats.proportion
A = [75,30] # 不良率
B = [300,300] #各組實驗總個數
z_value,p_value=statsmodels.stats.proportion.proportions_ztest(A, B, alternative='two-sided')
print(f"p_value:{p_value:6f} < a=0.05 >> 拒絕H_0，接受H_1")
# Out:
# H_0:p1=p2
# H_1:p1≠p2
# p_value:0.000001 < a=0.05 >> 拒絕H_0，接受H_1

# %%
# Out:
#   File "<ipython-input-21-560a6d63919d>", line 1
#     p_value:2f
#              ^
# SyntaxError: invalid syntax
