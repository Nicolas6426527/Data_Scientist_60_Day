# %% [markdown]
# 範例目標:<br>
# 1. 實做繪製圖表
# 2. 藉由圖表對資料有初步認識，並解釋圖表意義

# %% [markdown]
# 範例重點:<br>
# 1. 每一種圖表都有相對應用的情境，分辨情境並繪製對應圖表
# 2. 圖像化展現，方便對於資料有初步的理解

# %%
import pandas as pd
import numpy as np

# %%
#單一折線圖
ts = pd.Series(np.random.randn(200), index=pd.date_range('1/1/2020', periods=200))
ts = ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01    0.408772
# 2020-01-02    1.902864
# 2020-01-03    3.004919
# 2020-01-04    2.401729
# 2020-01-05    4.489267
#                 ...
# 2020-07-14   -2.325014
# 2020-07-15   -2.240285
# 2020-07-16   -3.084878
# 2020-07-17   -3.264279
# 2020-07-18   -2.916765
# Freq: D, Length: 200, dtype: float64
# <AxesSubplot:>

# %%
#多個折線圖同時畫出
df = pd.DataFrame(np.random.randn(200, 3), index=pd.date_range('1/1/2020', periods=200), columns=["A","B","C"])
df = df.cumsum()
print(df)
df.plot();
# Out:
#                    A          B         C
# 2020-01-01  1.062175   1.545960  0.313143
# 2020-01-02  0.981140   0.971219 -0.024275
# 2020-01-03  0.805088   0.184366 -0.424928
# 2020-01-04  1.367492  -0.577172  1.153676
# 2020-01-05  1.119139  -0.838316  0.588682
# ...              ...        ...       ...
# 2020-07-14  2.047676  19.447320  5.853765
# 2020-07-15  1.744037  18.195643  5.964874
# 2020-07-16  1.878861  18.369937  4.774730
# 2020-07-17  2.006561  16.943411  6.266647
# 2020-07-18  2.446892  17.504385  7.957803
#
# [200 rows x 3 columns]

# %%
#圓餅圖
df = pd.Series(np.random.rand(4), index=["A","B","C","D"],name="title")
print(df)
df.plot.pie()
# Out:
# A    0.114752
# B    0.844126
# C    0.610353
# D    0.894215
# Name: title, dtype: float64
# <AxesSubplot:ylabel='title'>

# %%
#長條圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.bar();
# Out:
#           A         B
# 0  0.351182  0.318318
# 1  0.897806  0.003340
# 2  0.632099  0.567870
# 3  0.772415  0.441826
# 4  0.570837  0.476311
# 5  0.282301  0.974770
# 6  0.582213  0.884616
# 7  0.904212  0.543904
# 8  0.734159  0.452428
# 9  0.475335  0.328955

# %%
df.plot.bar(stacked=True);

# %%
#箱型圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.boxplot()
# Out:
#           A         B
# 0  0.772122  0.297662
# 1  0.150642  0.919099
# 2  0.761859  0.444911
# 3  0.461002  0.876932
# 4  0.374707  0.214824
# 5  0.674743  0.192699
# 6  0.667188  0.921153
# 7  0.353126  0.343032
# 8  0.436113  0.929506
# 9  0.327474  0.935201

# %%
#散佈圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.scatter(x='A', y='B')
# Out:
#           A         B
# 0  0.810470  0.246334
# 1  0.752608  0.276965
# 2  0.424421  0.409977
# 3  0.909217  0.079332
# 4  0.376237  0.578638
# 5  0.603542  0.460691
# 6  0.039021  0.572284
# 7  0.499532  0.239554
# 8  0.526853  0.967803
# 9  0.077156  0.949759
