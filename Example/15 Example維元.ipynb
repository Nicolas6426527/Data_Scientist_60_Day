# %% [markdown]
# 範例目標:<br>
# 1. 實做繪製圖表
# 2. 藉由圖表對資料有初步認識，並解釋圖表意義

# %% [markdown]
# 範例重點:<br>
# 1. 每一種圖表都有相對應用的情境，分辨情境並繪製對應圖表
# 2. 圖像化展現，方便對於資料有初步的理解

# %%
import pandas as pd
import numpy as n
import matplotlib.pyplot as plt

# %%
#單一折線圖
ts = pd.Series(np.random.randn(200), index=pd.date_range('1/1/2020', periods=200))
ts = ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01    0.182976
# 2020-01-02   -1.094999
# 2020-01-03   -3.338978
# 2020-01-04   -5.334908
# 2020-01-05   -6.166664
#                 ...
# 2020-07-14   -7.215569
# 2020-07-15   -6.026452
# 2020-07-16   -4.292083
# 2020-07-17   -2.821662
# 2020-07-18   -3.742196
# Freq: D, Length: 200, dtype: float64
# <AxesSubplot:>

# %%
#多個折線圖同時畫出
df = pd.DataFrame(np.random.randn(200, 3), index=pd.date_range('1/1/2020', periods=200), columns=["A","B","C"])
df = df.cumsum()
print(df)
df.plot();
# Out:
#                     A          B          C
# 2020-01-01   1.669673   1.922691  -0.826532
# 2020-01-02   1.964919   0.470045  -1.572829
# 2020-01-03   0.557277  -0.458464  -1.875120
# 2020-01-04   0.084641  -0.175233  -2.357429
# 2020-01-05   0.905556  -2.041691  -2.458667
# ...               ...        ...        ...
# 2020-07-14  20.879817  14.335845 -20.279079
# 2020-07-15  20.734363  16.192377 -21.800450
# 2020-07-16  20.354786  16.073610 -21.598606
# 2020-07-17  19.361184  14.987280 -23.035793
# 2020-07-18  20.673198  16.285149 -24.227079
#
# [200 rows x 3 columns]

# %%
#圓餅圖
df = pd.Series(np.random.rand(4), index=["A","B","C","D"],name="title")
print(df)
df.plot.pie()
# Out:
# A    0.686126
# B    0.516835
# C    0.748920
# D    0.833173
# Name: title, dtype: float64
# <AxesSubplot:ylabel='title'>

# %%
#長條圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.bar();
# Out:
#           A         B
# 0  0.084299  0.977446
# 1  0.846215  0.225131
# 2  0.811922  0.701441
# 3  0.773484  0.023731
# 4  0.494629  0.782096
# 5  0.027951  0.101494
# 6  0.883174  0.484693
# 7  0.384187  0.799508
# 8  0.972668  0.547689
# 9  0.318383  0.163646

# %%
df.plot.bar(stacked=True);

# %%
#箱型圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.boxplot()
# Out:
#           A         B
# 0  0.724078  0.532409
# 1  0.647820  0.751725
# 2  0.215470  0.094194
# 3  0.699943  0.664996
# 4  0.452987  0.264577
# 5  0.021149  0.873577
# 6  0.153595  0.297432
# 7  0.759732  0.155069
# 8  0.858016  0.235673
# 9  0.451235  0.687544
# <AxesSubplot:>

# %%
#散佈圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.scatter(x='A', y='B')
# Out:
#           A         B
# 0  0.250281  0.049379
# 1  0.038554  0.917549
# 2  0.344092  0.703134
# 3  0.382830  0.404733
# 4  0.842170  0.684152
# 5  0.716856  0.788748
# 6  0.274192  0.827123
# 7  0.632657  0.212149
# 8  0.235825  0.557149
# 9  0.960722  0.638800
# <AxesSubplot:xlabel='A', ylabel='B'>
