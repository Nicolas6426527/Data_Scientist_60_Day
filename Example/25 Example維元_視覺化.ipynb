# %% [markdown]
# 目標: 了解利用 PANDAS 整理資料, 利用資料視覺化可以很快的判斷結果
#
# 重點: 資料整理與視覺化可以加速理解機器學習

# %%
# 載入相關的程式庫
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# 可以使用本地的Python 程式
#
# 若是想嘗試使用 Colab 請注意一下
#
# 不使用 Colab 可以跳過

# %%
## 若是想嘗試使用 Colab 請注意一下
# 新增網路硬碟
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
#drive.mount('/gdrive')
import os
os.getcwd()

# %%
#設定Google Drive路徑
root = "/gdrive"
path = "/gdrive/My Drive/Colab Notebooks/Visualization"

os.chdir(path)
os.getcwd()
# 手動上傳資料集到目前工作路徑

# %% [markdown]
# # 本地運行範例程式由此開始

# %%
### 利用 PANDAS 取得酒的品質資料
# 請記得把CSV檔放在當前的工作目錄 

#如何察知工作目錄:
import os
os.getcwd()

df_red = pd.read_csv("winequality_red.csv")
df_white = pd.read_csv("winequality_white.csv")

# %%
#資料整理
df_red["color"] = "R"
df_white["color"] = "W"

#整合紅酒與白酒的資料
df_all=pd.concat([df_red,df_white],axis=0)

# 檢查合併後的資料集
df_all.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5     R
# 1      9.8        5     R
# ...

# %%
# 重新命名特徵
df_all.rename(columns={'fixed acidity': 'fixed_acidity','citric acid':'citric_acid',
                       'volatile acidity':'volatile_acidity','residual sugar':'residual_sugar',
                       'free sulfur dioxide':'free_sulfur_dioxide',
                       'total sulfur dioxide':'total_sulfur_dioxide'}, inplace=True)
# 檢查合併後的資料集
df_all.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5     R
# 1      9.8        5     R
# ...

# %%
# 資料整理之前
#酒類的品質是首要, 所以我們可以以 quality 為 Y lable
sns.histplot(df_all["quality"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Count'>

# %%
#處理缺失值
df = pd.get_dummies(df_all, columns=["color"])
df_all.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
#可以使用 info() 方法瞭解有關資料集屬性的更多資訊。特別是行和列的數量、列名稱、它們的數據類型和空值數。
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %%
#要瞭解數據集的統計摘要,即記錄數、平均值、標準差、最小值和最大值,我們使用描述()。
df_all.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
#所有數值數據數值不一, 難以由圖表一眼看清
#在垂直軸上計數,在水平軸上使用值範圍。hist 函數通過將所有屬性繪製在一起使操作變得簡單。
df_all.hist(bins=10, color='lightblue',edgecolor='blue',linewidth=1.0,
          xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout()#們發現 label 被重疊到了, 若要逐一調整十分麻

# %% [markdown]
# # tight_layout 介紹
#
# 上圖, 我們發現 label 被重疊到了, 若要逐一調整十分麻煩,
#
# 這時, 可以考慮tight_layout
#
# tight_layout提供rect參數，表示一個外界的框框:(x1, y1, x2, y2)默認是(0, 0, 1, 1)
#
# (x1, y1)矩形限制框左下角座標
#
# (x2, y2)矩形限制框右上角座標

# %%
#建立一個Figure（空的顯示區）
fig = plt.figure()

#直接製圖在剛剛建立的figure
ax1 = plt.subplot(221)
ax2 = plt.subplot(223)
ax3 = plt.subplot(122)

#避免多個圖重疊，使用tight_layout分開, 可以節省新增Figure的軸的動作
plt.tight_layout()

# %%
df_all.hist(bins=10, color='lightblue',edgecolor='blue',linewidth=1.0,
          xlabelsize=8, ylabelsize=8, grid=False)    

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %% [markdown]
# # 資料觀察
#
# 從上圖來看, 我們可以發現, 數據多的幾個特徵:
#
# alcohol, pH, total_sulfur_dioxide, fixedacidity, citric_acid, volatile_acidity
#
# 可以挑選幾個特徵來看彼此的關係

# %%
# Plot multiple seaborn histogram in single graph
plt.figure(figsize=(7,5))
sns.histplot(df_all["quality"], bins=10, label="quality")
sns.histplot(df_all["pH"], bins=10, label="pH")
sns.histplot(df_all["alcohol"], bins=10, label = "alcohol")

# %% [markdown]
# # 上圖的解讀
#
# 比對資料整理前, Quality 的分布, 我們可以發現 pH 跟Quality呈現高度正相關
#
# alcohol 對 Quality 的影響被侷促

# %%
# 箱形圖（Box plot），又稱為盒鬚圖、盒式圖、盒狀圖或箱線圖，是一種用作顯示一組數據分散情況資料的統計圖
# 用來觀察每個特徵的離群值
df_all.boxplot(color='#556270')    
plt.tight_layout(rect=(0, 0, 3, 3))

# %%
# 只看幾個特定特徵
df_all.boxplot(column=['volatile_acidity','pH','quality'], color='#556270')    
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %%
# %config InlineBackend.figure_format = 'retina'
#以提高jupyter notebook圖形顯示的解析度

# %matplotlib inline
#直接顯示

# %% [markdown]
# # 熱力圖
#
# 是一個以顏色變化來顯示數據的矩陣。簡單來說，就是用依據數字的不同，使用不同的顏色來呈現數據
#
# 利用熱力圖可以看資料表裡多個特徵兩兩的相似度。

# %%
# 最直接的做法是把資料集丟給heatmap函數
sns.heatmap(df_all.corr())

# 可以看到熱力圖主要展示的是二維數據的數據關係
# 不同大小的值對應不同的顏色深淺
# df_all.corr() - 把 string transfer to float type
# Out:
# <AxesSubplot:>

# %%
# 加上標記data
sns.heatmap(df_all.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# 這個資料集包括了平均數, 標準差, 一定區間的數值
# 所以, 我們可以考慮使用 bootstrap 幫忙繪製圖表包含 mean, median and mid-range statistics.
s = pd.Series(df_all['quality'])
pd.plotting.bootstrap_plot(s, samples=500)
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

df_red = pd.read_csv(r'C:\Users\jiao\Desktop\cupoy\python資料科學_D22\winequality_datasets\winequality-red.csv', sep = ';')
df_white = pd.read_csv(r'C:\Users\jiao\Desktop\cupoy\python資料科學_D22\winequality_datasets\winequality-white.csv', sep = ';')

df_red.info(),df_white.info()

df_red.duplicated().sum(),df_white.duplicated().sum()

df_red.drop_duplicates(inplace = True)
df_white.drop_duplicates(inplace = True)

df_red.isnull().sum().sum(),df_white.isnull().sum().sum()

df_wine = df_red.append(df_white)
df_wine.to_csv('winequality.csv', index=False)

df_wine = pd.read_csv(r'C:\Users\jiao\Desktop/cupoy\python資料科學_D22\winequality.csv')

df_wine.info()

df_wine.hist(color='lightblue',edgecolor='blue',linewidth=1.0,xlabelsize=8, ylabelsize=8, grid=False)
plt.tight_layout(rect=(1,1,3,3))

f, ax = plt.subplots(figsize=(10, 6))
b = sns.heatmap(df_wine.corr(), annot=True, linewidths=.05, ax=ax)
f.subplots_adjust(top=0.93)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
title= f.suptitle('Correlation Heatmap for wine attributes', fontsize=12)

sns.jointplot(data=df_wine, x="fixed acidity", y="volatile acidity", kind = 'reg')

sns.jointplot(data=df_wine, x="alcohol", y="chlorides", kind = 'reg')

sns.jointplot(data=df_wine, x="volatile acidity", y="citric acid", kind = 'reg')

sns.violinplot(data=df_wine, x="quality", y="sulphates")
